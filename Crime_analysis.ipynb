# %%
# Dependencies and Setup
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import requests
import time
from scipy.stats import linregress

# %%
# Load the CSV file
df = pd.read_csv('C:/Users/bolit/OneDrive/Desktop/Group_Project_1/Data/national_data.csv')

# Specify the order of your columns
column_order = ['Year', 'Aggravated Assault', 'Drug Abuse Violations', 'Weapons: Carrying, Possessing, Etc.']

# Reorder the dataframe
df = df[column_order]
df
# Out:
#    Year  Aggravated Assault  Drug Abuse Violations  \
# 0  2011              314952                1211288
# 1  2012              314551                1247777
# 2  2013              305315                1288463
# 3  2014              298789                1252950
# 4  2015              304086                1196442
# 5  2016              316530                1302382
# 6  2017              342286                1472365
# 7  2018              324936                1356959
# 8  2019              327775                1282161
# 9  2020              302187                 894383
#
#    Weapons: Carrying, Possessing, Etc.
# 0                               121366
# 1                               120762
# 2                               113716
# 3                               112860
# 4                               116869
# 5                               130237
# 6                               140726
# 7                               137432
# 8                               127298
# ...

# %%
# Load the CSV file
df = pd.read_csv('C:/Users/bolit/OneDrive/Desktop/Group_Project_1/Data/national_data.csv')

# Calculate total counts
total_aggravated_assault = df['Aggravated Assault'].sum()
total_drug_abuse_violations = df['Drug Abuse Violations'].sum()
total_weapons_violations = df['Weapons: Carrying, Possessing, Etc.'].sum()

print(f"Total Aggravated Assault: {total_aggravated_assault}")
print(f"Total Drug Abuse Violations: {total_drug_abuse_violations}")
print(f"Total Weapons Violations: {total_weapons_violations}")
# Out:
# Total Aggravated Assault: 3151407
# Total Drug Abuse Violations: 12505170
# Total Weapons Violations: 1248572

# %%
# Load the CSV file
df = pd.read_csv('C:/Users/bolit/OneDrive/Desktop/Group_Project_1/Data/national_data.csv')


df['Year'] = pd.to_datetime(df['Year'], format='%Y')  
df.set_index('Year', inplace=True)

# Plot the graph
plt.figure(figsize=(10,5))
plt.plot(df['Aggravated Assault'], marker='*')

# Specify title and labels
plt.title('Year vs Aggravated Assault')
plt.xlabel('Year')
plt.ylabel('Aggravated Assault')

# Show the plot
plt.show()

# %%
# Load the CSV file
df = pd.read_csv('C:/Users/bolit/OneDrive/Desktop/Group_Project_1/Data/national_data.csv')

# Convert 'Year' column to datetime and set it as the index
df['Year'] = pd.to_datetime(df['Year'], format='%Y')
df.set_index('Year', inplace=True)

# Create a scatter plot for 'Year' vs 'Aggravated Assault'
plt.figure(figsize=(8, 5))
plt.scatter(df.index.year, df['Aggravated Assault'], label='Data')

# Calculate the regression line
slope, intercept, r_value, p_value, std_err = linregress(df.index.year, df['Aggravated Assault'])
line = slope * df.index.year + intercept

# Plot the regression line
plt.plot(df.index.year, line, 'k', label=f'y={slope:.2f}x+{intercept:.2f}\nr={r_value:.2f}, p={p_value:.2f}')

# Specify title and labels
plt.title('Year vs Aggravated Assault')
plt.xlabel('Year')
plt.ylabel('Aggravated Assault')

# Show the legend
plt.legend()

# Show the plot
plt.show()

# %%
# Load the CSV file
df = pd.read_csv('C:/Users/bolit/OneDrive/Desktop/Group_Project_1/Data/national_data.csv')



df['Year'] = pd.to_datetime(df['Year'], format='%Y')  
df.set_index('Year', inplace=True)
plt.figure(figsize=(8,5))
plt.scatter(df.index.year, df['Drug Abuse Violations'])

# Calculate the regression line
slope, intercept, r_value, p_value, std_err = linregress(df.index.year, df['Drug Abuse Violations'])
line = slope * df.index.year + intercept

# Plot the regression line
plt.plot(df.index.year, line, 'r', label=f'y={slope:.2f}x+{intercept:.2f}\nr={r_value:.2f}, p={p_value:.2f}')

# Specify title and labels
plt.title('Year vs Drug Abuse Violations')
plt.xlabel('Year')
plt.ylabel('Drug Abuse Violations')

# Show the legend
plt.legend()

# Show the plot
plt.show()

# %%
# Load the CSV file
df = pd.read_csv('C:/Users/bolit/OneDrive/Desktop/Group_Project_1/Data/national_data.csv')


df['Year'] = pd.to_datetime(df['Year'], format='%Y')  
df.set_index('Year', inplace=True)

# Plot the graph
plt.figure(figsize=(8,5))
plt.plot(df['Drug Abuse Violations'], marker='p')

# Specify title and labels
plt.title('Year vs Drug Abuse Violations')
plt.xlabel('Year')
plt.ylabel('Drug Abuse Violations')

# Show the plot
plt.show()

# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
from scipy.stats import linregress

# Load the CSV file
df = pd.read_csv('C:/Users/bolit/OneDrive/Desktop/Group_Project_1/Data/national_data.csv')


df['Year'] = pd.to_datetime(df['Year'], format='%Y')  
df.set_index('Year', inplace=True)
plt.figure(figsize=(8,5))
plt.scatter(df.index.year, df['Weapons: Carrying, Possessing, Etc.'])

# Calculate the regression line
slope, intercept, r_value, p_value, std_err = linregress(df.index.year, df['Weapons: Carrying, Possessing, Etc.'])
line = slope * df.index.year + intercept

# Plot the regression line
plt.plot(df.index.year, line, 'g', label=f'y={slope:.2f}x+{intercept:.2f}\nr={r_value:.2f}, p={p_value:.2f}')

# Specify title and labels
plt.title('Year vs Weapons: Carrying, Possessing, Etc.')
plt.xlabel('Year')
plt.ylabel('Weapons: Carrying, Possessing, Etc.')

# Show the legend
plt.legend()

# Show the plot
plt.show()

# %%
# Load the CSV file
df = pd.read_csv('C:/Users/bolit/OneDrive/Desktop/Group_Project_1/Data/national_data.csv')


df['Year'] = pd.to_datetime(df['Year'], format='%Y')  
df.set_index('Year', inplace=True)

# Plot the graph
plt.figure(figsize=(8,5))
plt.plot(df['Weapons: Carrying, Possessing, Etc.'], marker='p')



# Specify title and labels
plt.title('Year vs Weapons: Carrying, Possessing, Etc. ')
plt.xlabel('Year')
plt.ylabel('Weapons: Carrying, Possessing, Etc.')

# Show the plot
plt.show()

# %%
# Load the CSV file
df = pd.read_csv('C:/Users/bolit/OneDrive/Desktop/Group_Project_1/Data/national_data.csv')

df['Year'] = pd.to_datetime(df['Year'], format='%Y')  
df.set_index('Year', inplace=True)

# Plot the graph
plt.figure(figsize=(8,6))

# Plot Various Violations
plt.plot(df['Aggravated Assault'], marker='o', color='blue', label='Aggravated Assault')
plt.plot(df['Drug Abuse Violations'], marker='o', color='green', label='Drug Abuse Violations')
plt.plot(df['Weapons: Carrying, Possessing, Etc.'], marker='o', color='orange', label='Weapons: Carrying, Possessing, Etc.')

# Specify title and labels
plt.title('Year vs Various Violations')
plt.xlabel('Year')
plt.ylabel('Count')

# Show legend
plt.legend()

# Show the plot
plt.show()

# %%
# Load the CSV file
df = pd.read_csv('C:/Users/bolit/OneDrive/Desktop/Group_Project_1/Data/national_data.csv')

df['Year'] = pd.to_datetime(df['Year'], format='%Y')  
df.set_index('Year', inplace=True)

# Select only the desired columns for boxplot
selected_columns = df[['Aggravated Assault', 'Drug Abuse Violations', 'Weapons: Carrying, Possessing, Etc.']]

# Create boxplot
plt.figure(figsize=(10,6))
plt.boxplot([df[column].dropna() for column in selected_columns], labels=selected_columns.columns)

# Specify title and y-label
plt.title('Boxplot of Violations')
plt.ylabel('Count')

# Show the plot
plt.show()

# %%
# Load the CSV file
df = pd.read_csv('C:/Users/bolit/OneDrive/Desktop/Group_Project_1/Data/national_data.csv')

# Calculate total counts
total_aggravated_assault = df['Aggravated Assault'].sum()
total_drug_abuse_violations = df['Drug Abuse Violations'].sum()
total_weapons_violations = df['Weapons: Carrying, Possessing, Etc.'].sum()

# Prepare data for pie chart
violations = ['Aggravated Assault', 'Drug Abuse Violations', 'Weapons Violations']
totals = [total_aggravated_assault, total_drug_abuse_violations, total_weapons_violations]
colors = ['blue', 'red', 'orange'] 
explode = (0.1, 0.1, 0.1)  

# Create pie chart
plt.figure(figsize=(10,6))
plt.pie(totals, labels=violations, autopct='%1.1f%%', startangle=140, shadow=True, colors=colors, explode=explode)

# Specify title
plt.title('Percentage of Total Violations')

# Show the plot
plt.show()

# %%
# Load the CSV file
df = pd.read_csv('C:/Users/bolit/OneDrive/Desktop/Group_Project_1/Data/national_data.csv')

df['Year'] = pd.to_datetime(df['Year'], format='%Y')  
df.set_index('Year', inplace=True)  

# List of column names
columns = ['Aggravated Assault', 'Drug Abuse Violations', 'Weapons: Carrying, Possessing, Etc.']

# Create a stacked area plot
plt.figure(figsize=(10,6))
plt.stackplot(df.index, df[columns].transpose(), labels=columns)

# Specify the title, labels and legend
plt.title('Stacked Area Plot of Violations Over Time')
plt.xlabel('Year')
plt.ylabel('Number of Violations')
plt.legend(loc='upper left')

# Display the plot
plt.show()

# %%
# Load the CSV file
df = pd.read_csv('C:/Users/bolit/OneDrive/Desktop/Group_Project_1/Data/national_data.csv')

# Select relevant columns and calculate correlation matrix
corr_matrix = df[['Aggravated Assault', 'Drug Abuse Violations', 'Weapons: Carrying, Possessing, Etc.']].corr()

# Create the heatmap
plt.figure(figsize=(6,4))
sns.heatmap(corr_matrix, annot=True, cmap='coolwarm', vmin=-1, vmax=1)
plt.title('Correlation Matrix of Violations')

# Display the plot
plt.show()

# %% [markdown]
# The State of Oregon

# %%
# Load the CSV file
df = pd.read_csv('C:/Users/bolit/OneDrive/Desktop/Group_Project_1/Data/oregon_data.csv')

# Specify the order of your columns
column_order = ['Year', 'Aggravated Assault', 'Drug Abuse Violations', 'Weapons: Carrying, Possessing, Etc.']

# Reorder the dataframe
df = df[column_order]
df
# Out:
#    Year  Aggravated Assault  Drug Abuse Violations  \
# 0  2011                3064                  19342
# 1  2012                2895                  19936
# 2  2013                1298                  10687
# 3  2014                1992                  14398
# 4  2015                2329                  13007
# 5  2016                2951                  14824
# 6  2017                2896                  16230
# 7  2018                3554                  15731
# 8  2019                3938                  14999
# 9  2020                3655                   9088
#
#    Weapons: Carrying, Possessing, Etc.
# 0                                 1747
# 1                                 1767
# 2                                  884
# 3                                 1426
# 4                                 1438
# 5                                 1836
# 6                                 2170
# 7                                 2440
# 8                                 2381
# ...

# %%
# Load the CSV file
df = pd.read_csv('C:/Users/bolit/OneDrive/Desktop/Group_Project_1/Data/oregon_data.csv')

# Calculate total counts
total_aggravated_assault = df['Aggravated Assault'].sum()
total_drug_abuse_violations = df['Drug Abuse Violations'].sum()
total_weapons_violations = df['Weapons: Carrying, Possessing, Etc.'].sum()

print(f"Total Aggravated Assault: {total_aggravated_assault}")
print(f"Total Drug Abuse Violations: {total_drug_abuse_violations}")
print(f"Total Weapons Violations: {total_weapons_violations}")
# Out:
# Total Aggravated Assault: 28572
# Total Drug Abuse Violations: 148242
# Total Weapons Violations: 18194

# %%
# Load the CSV file
df = pd.read_csv('C:/Users/bolit/OneDrive/Desktop/Group_Project_1/Data/oregon_data.csv')

df['Year'] = pd.to_datetime(df['Year'], format='%Y')  
df.set_index('Year', inplace=True)

# Plot the graph
plt.figure(figsize=(8,6))

# Plot Various Violations
plt.plot(df['Aggravated Assault'], marker='o', color='blue', label='Aggravated Assault')
plt.plot(df['Drug Abuse Violations'], marker='o', color='green', label='Drug Abuse Violations')
plt.plot(df['Weapons: Carrying, Possessing, Etc.'], marker='o', color='orange', label='Weapons: Carrying, Possessing, Etc.')

# Specify title and labels
plt.title('Year vs Various Violations')
plt.xlabel('Year')
plt.ylabel('Count')

# Show legend
plt.legend()

# Show the plot
plt.show()

# %%
# Load the CSV file
df = pd.read_csv('C:/Users/bolit/OneDrive/Desktop/Group_Project_1/Data/oregon_data.csv')

df['Year'] = pd.to_datetime(df['Year'], format='%Y')  
df.set_index('Year', inplace=True)

# Plot the scatter plots and regression lines
plt.figure(figsize=(10,5))

for column, color in [('Aggravated Assault', 'blue'), ('Drug Abuse Violations', 'green'), ('Weapons: Carrying, Possessing, Etc.', 'orange')]:
    # Scatter plot
    plt.scatter(df.index.year, df[column], color=color)

    # Calculate the regression line
    slope, intercept, r_value, p_value, std_err = linregress(df.index.year, df[column])
    line = slope * df.index.year + intercept

    # Plot the regression line
    plt.plot(df.index.year, line, color=color, label=f'{column}: y={slope:.2f}x+{intercept:.2f}\nr={r_value:.2f}, p={p_value:.2f}')

# Specify title and labels
plt.title('Year vs Various Violations')
plt.xlabel('Year')

# Show the legend
plt.legend()

# Show the plot
plt.show()

# %%
# Load the CSV file
df = pd.read_csv('C:/Users/bolit/OneDrive/Desktop/Group_Project_1/Data/oregon_data.csv')

# Calculate total counts
total_aggravated_assault = df['Aggravated Assault'].sum()
total_drug_abuse_violations = df['Drug Abuse Violations'].sum()
total_weapons_violations = df['Weapons: Carrying, Possessing, Etc.'].sum()

# Prepare data for pie chart
violations = ['Aggravated Assault', 'Drug Abuse Violations', 'Weapons Violations']
totals = [total_aggravated_assault, total_drug_abuse_violations, total_weapons_violations]
colors = ['blue', 'red', 'orange'] 
explode = (0.1, 0.1, 0.1)  

# Create pie chart
plt.figure(figsize=(10,6))
plt.pie(totals, labels=violations, autopct='%1.1f%%', startangle=140, shadow=True, colors=colors, explode=explode)

# Specify title
plt.title('Percentage of Total Violations')

# Show the plot
plt.show()

# %%
# Load the CSV file
df = pd.read_csv('C:/Users/bolit/OneDrive/Desktop/Group_Project_1/Data/oregon_data.csv')

df['Year'] = pd.to_datetime(df['Year'], format='%Y')  
df.set_index('Year', inplace=True)  

# List of column names
columns = ['Aggravated Assault', 'Drug Abuse Violations', 'Weapons: Carrying, Possessing, Etc.']

# Create a stacked area plot
plt.figure(figsize=(10,6))
plt.stackplot(df.index, df[columns].transpose(), labels=columns)

# Specify the title, labels and legend
plt.title('Stacked Area Plot of Violations Over Time')
plt.xlabel('Year')
plt.ylabel('Number of Violations')
plt.legend(loc='upper left')

# Display the plot
plt.show()

# %%
# Load the CSV file
df = pd.read_csv('C:/Users/bolit/OneDrive/Desktop/Group_Project_1/Data/oregon_data.csv')

# Select relevant columns and calculate correlation matrix
corr_matrix = df[['Aggravated Assault', 'Drug Abuse Violations', 'Weapons: Carrying, Possessing, Etc.']].corr()

# Create the heatmap
plt.figure(figsize=(6,4))
sns.heatmap(corr_matrix, annot=True, cmap='coolwarm', vmin=-1, vmax=1)
plt.title('Correlation Matrix of Violations')

# Display the plot
plt.show()

# %%
# Load the CSV file
df = pd.read_csv('C:/Users/bolit/OneDrive/Desktop/Group_Project_1/Data/oregon_data.csv')

df['Year'] = pd.to_datetime(df['Year'], format='%Y')  
df.set_index('Year', inplace=True)

# Select only the desired columns for boxplot
selected_columns = df[['Aggravated Assault', 'Drug Abuse Violations', 'Weapons: Carrying, Possessing, Etc.']]

# Create boxplot
plt.figure(figsize=(10,6))
plt.boxplot([df[column].dropna() for column in selected_columns], labels=selected_columns.columns)

# Specify title and y-label
plt.title('Boxplot of Violations')
plt.ylabel('Count')

# Show the plot
plt.show()

# %% [markdown]
# The State of Washington

# %%
# Load the CSV file
df = pd.read_csv('C:/Users/bolit/OneDrive/Desktop/Group_Project_1/Data/Washington_data.csv')

# Specify the order of your columns
column_order = ['Year', 'Aggravated Assault', 'Drug Abuse Violations', 'Weapons: Carrying, Possessing, Etc.']

# Reorder the dataframe
df = df[column_order]
df
# Out:
#    Year  Aggravated Assault  Drug Abuse Violations  \
# 0  2011                3988                  14210
# 1  2012                5112                  13522
# 2  2013                5268                  11360
# 3  2014                5249                  11144
# 4  2015                5373                  11056
# 5  2016                5536                  11052
# 6  2017                5932                  12201
# 7  2018                6253                  11882
# 8  2019                6189                  12313
# 9  2020                6022                   8173
#
#    Weapons: Carrying, Possessing, Etc.
# 0                                 1720
# 1                                 1849
# 2                                 1852
# 3                                 1744
# 4                                 1777
# 5                                 1711
# 6                                 1805
# 7                                 1912
# 8                                 1980
# ...

# %%
# Load the CSV file
df = pd.read_csv('C:/Users/bolit/OneDrive/Desktop/Group_Project_1/Data/Washington_data.csv')

# Calculate total counts
total_aggravated_assault = df['Aggravated Assault'].sum()
total_drug_abuse_violations = df['Drug Abuse Violations'].sum()
total_weapons_violations = df['Weapons: Carrying, Possessing, Etc.'].sum()

print(f"Total Aggravated Assault: {total_aggravated_assault}")
print(f"Total Drug Abuse Violations: {total_drug_abuse_violations}")
print(f"Total Weapons Violations: {total_weapons_violations}")
# Out:
# Total Aggravated Assault: 54922
# Total Drug Abuse Violations: 116913
# Total Weapons Violations: 18047

# %%
# Load the CSV file
df = pd.read_csv('C:/Users/bolit/OneDrive/Desktop/Group_Project_1/Data/Washington_data.csv')

df['Year'] = pd.to_datetime(df['Year'], format='%Y')  
df.set_index('Year', inplace=True)

# Plot the graph
plt.figure(figsize=(8,6))

# Plot Various Violations
plt.plot(df['Aggravated Assault'], marker='o', color='blue', label='Aggravated Assault')
plt.plot(df['Drug Abuse Violations'], marker='o', color='green', label='Drug Abuse Violations')
plt.plot(df['Weapons: Carrying, Possessing, Etc.'], marker='o', color='orange', label='Weapons: Carrying, Possessing, Etc.')

# Specify title and labels
plt.title('Year vs Various Violations')
plt.xlabel('Year')
plt.ylabel('Count')

# Show legend
plt.legend()

# Show the plot
plt.show()

# %%
# Load the CSV file
df = pd.read_csv('C:/Users/bolit/OneDrive/Desktop/Group_Project_1/Data/Washington_data.csv')

df['Year'] = pd.to_datetime(df['Year'], format='%Y')  
df.set_index('Year', inplace=True)

# Plot the scatter plots and regression lines
plt.figure(figsize=(10,5))

for column, color in [('Aggravated Assault', 'blue'), ('Drug Abuse Violations', 'green'), ('Weapons: Carrying, Possessing, Etc.', 'orange')]:
    # Scatter plot
    plt.scatter(df.index.year, df[column], color=color)

    # Calculate the regression line
    slope, intercept, r_value, p_value, std_err = linregress(df.index.year, df[column])
    line = slope * df.index.year + intercept

    # Plot the regression line
    plt.plot(df.index.year, line, color=color, label=f'{column}: y={slope:.2f}x+{intercept:.2f}\nr={r_value:.2f}, p={p_value:.2f}')

# Specify title and labels
plt.title('Year vs Various Violations')
plt.xlabel('Year')

# Show the legend
plt.legend()

# Show the plot
plt.show()

# %%
# Load the CSV file
df = pd.read_csv('C:/Users/bolit/OneDrive/Desktop/Group_Project_1/Data/Washington_data.csv')

# Calculate total counts
total_aggravated_assault = df['Aggravated Assault'].sum()
total_drug_abuse_violations = df['Drug Abuse Violations'].sum()
total_weapons_violations = df['Weapons: Carrying, Possessing, Etc.'].sum()

# Prepare data for pie chart
violations = ['Aggravated Assault', 'Drug Abuse Violations', 'Weapons Violations']
totals = [total_aggravated_assault, total_drug_abuse_violations, total_weapons_violations]
colors = ['blue', 'red', 'orange'] 
explode = (0.1, 0.1, 0.1)  

# Create pie chart
plt.figure(figsize=(10,6))
plt.pie(totals, labels=violations, autopct='%1.1f%%', startangle=140, shadow=True, colors=colors, explode=explode)

# Specify title
plt.title('Percentage of Total Violations')

# Show the plot
plt.show()

# %%
# Load the CSV file
df = pd.read_csv('C:/Users/bolit/OneDrive/Desktop/Group_Project_1/Data/Washington_data.csv')

df['Year'] = pd.to_datetime(df['Year'], format='%Y')  
df.set_index('Year', inplace=True)  

# List of column names
columns = ['Aggravated Assault', 'Drug Abuse Violations', 'Weapons: Carrying, Possessing, Etc.']

# Create a stacked area plot
plt.figure(figsize=(10,6))
plt.stackplot(df.index, df[columns].transpose(), labels=columns)

# Specify the title, labels and legend
plt.title('Stacked Area Plot of Violations Over Time')
plt.xlabel('Year')
plt.ylabel('Number of Violations')
plt.legend(loc='upper left')

# Display the plot
plt.show()

# %%
# Load the CSV file
df = pd.read_csv('C:/Users/bolit/OneDrive/Desktop/Group_Project_1/Data/Washington_data.csv')

# Select relevant columns and calculate correlation matrix
corr_matrix = df[['Aggravated Assault', 'Drug Abuse Violations', 'Weapons: Carrying, Possessing, Etc.']].corr()

# Create the heatmap
plt.figure(figsize=(6,4))
sns.heatmap(corr_matrix, annot=True, cmap='coolwarm', vmin=-1, vmax=1)
plt.title('Correlation Matrix of Violations')

# Display the plot
plt.show()

# %%
# Load the CSV file
df = pd.read_csv('C:/Users/bolit/OneDrive/Desktop/Group_Project_1/Data/Washington_data.csv')

df['Year'] = pd.to_datetime(df['Year'], format='%Y')  
df.set_index('Year', inplace=True)

# Select only the desired columns for boxplot
selected_columns = df[['Aggravated Assault', 'Drug Abuse Violations', 'Weapons: Carrying, Possessing, Etc.']]

# Create boxplot
plt.figure(figsize=(10,6))
plt.boxplot([df[column].dropna() for column in selected_columns], labels=selected_columns.columns)

# Specify title and y-label
plt.title('Boxplot of Violations')
plt.ylabel('Count')

# Show the plot
plt.show()
