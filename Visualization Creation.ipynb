# %%
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import requests
import time
from scipy.stats import linregress

# %%
oregon_df = pd.read_csv("Data/oregon_data.csv")

oregon_df.head()
# Out:
#    Unnamed: 0  Year State  Aggravated Assault  \
# 0           0  2011    OR                3064
# 1           1  2012    OR                2895
# 2           2  2013    OR                1298
# 3           3  2014    OR                1992
# 4           4  2015    OR                2329
#
#    All Other Offenses (except traffic)  Arson  Burglary  \
# 0                                20733    264      2578
# 1                                19739    260      2624
# 2                                10180    106      1024
# 3                                15471    139      1415
# 4                                19232    169      1554
#
#    Curfew and Loitering Law Violations  Disorderly Conduct  \
# 0                                  852               10230
# 1                                 1156               10458
# 2                                  411                3499
# 3                                  526                6215
# ...

# %%
oregon_aggassault = oregon_df["Aggravated Assault"]
year = oregon_df["Year"]

plt.plot(year, oregon_aggassault)
plt.xlabel("Year")
plt.ylabel("Number of Aggravated Assault Cases")
plt.title("Oregon-Aggravated Assault Cases 2011-2020")

plt.show()

# %%
oregon_drug_abuse = oregon_df["Drug Abuse Violations"]
year = oregon_df["Year"]

plt.plot(year, oregon_drug_abuse)
plt.xlabel("Year")
plt.ylabel("Number of Drug Abuse Violations")
plt.title("Oregon-Drug Abuse Violations 2011-2020")

plt.show()

# %%
oregon_weapons = oregon_df["Weapons: Carrying, Possessing, Etc."]
year = oregon_df["Year"]

plt.plot(year, oregon_weapons)
plt.xlabel("Year")
plt.ylabel("Number of Weapons Violations")
plt.title("Oregon-Weapons Violations 2011-2020")

plt.show()

# %%
oregon_aggassault = oregon_df["Aggravated Assault"]
oregon_weapons = oregon_df["Weapons: Carrying, Possessing, Etc."]
oregon_drug_abuse = oregon_df["Drug Abuse Violations"]
year = oregon_df["Year"]

plt.plot(year, oregon_aggassault, color="red", marker=".")
plt.plot(year, oregon_weapons, marker=".")
plt.plot(year, oregon_drug_abuse, color ="green", marker=".")

#plt.xlabel("Year")
#plt.ylabel("Number of Aggravated Assault Cases")
#plt.title("Oregon-Aggravated Assault Cases 2011-2020")

plt.show()

# %%
washington_df = pd.read_csv("Data/washington_data.csv")

washington_df.head()
# Out:
#    Unnamed: 0  Year State  Aggravated Assault  \
# 0           0  2011    WA                3988
# 1           1  2012    WA                5112
# 2           2  2013    WA                5268
# 3           3  2014    WA                5249
# 4           4  2015    WA                5373
#
#    All Other Offenses (except traffic)  Arson  Burglary  \
# 0                                41460    211      4192
# 1                                48927    205      4827
# 2                                57296    175      5235
# 3                                54746    211      5016
# 4                                64011    188      4912
#
#    Curfew and Loitering Law Violations  Disorderly Conduct  \
# 0                                   60                3897
# 1                                   25                3416
# 2                                    7                3535
# 3                                   12                3275
# ...

# %%
washington_aggassault = washington_df["Aggravated Assault"]
year = washington_df["Year"]

plt.plot(year, washington_aggassault)
plt.xlabel("Year")
plt.ylabel("Number of Aggravated Assault Cases")
plt.title("Washington-Aggravated Assault Cases 2011-2020")

plt.show()

# %%
washington_drug_abuse = washington_df["Drug Abuse Violations"]
year = washington_df["Year"]

plt.plot(year, washington_drug_abuse)
plt.xlabel("Year")
plt.ylabel("Number of Drug Abuse Violations")
plt.title("Washington-Drug Abuse Violations 2011-2020")

plt.show()

# %%
washington_weapons = washington_df["Weapons: Carrying, Possessing, Etc."]
year = washington_df["Year"]

plt.plot(year, washington_weapons)
plt.xlabel("Year")
plt.ylabel("Number of Weapons Violations")
plt.title("Washington-Weapons Violations 2011-2020")

plt.show()

# %%
national_df = pd.read_csv("Data/national_data.csv")

national_df.head()
# Out:
#    Unnamed: 0  Year     State  Aggravated Assault  \
# 0           0  2011  National              314952
# 1           1  2012  National              314551
# 2           2  2013  National              305315
# 3           3  2014  National              298789
# 4           4  2015  National              304086
#
#    All Other Offenses (except traffic)  Arson  Burglary  \
# 0                              2844915   9265    235515
# 1                              2806813   9380    230997
# 2                              2730774   8515    205997
# 3                              2613454   7590    192163
# 4                              2634107   7170    176289
#
#    Curfew and Loitering Law Violations  Disorderly Conduct  \
# 0                                61336              466390
# 1                                59274              445091
# 2                                48344              392741
# 3                                42242              352405
# ...

# %%
national_aggassault = national_df["Aggravated Assault"]
year = national_df["Year"]

plt.plot(year, national_aggassault)
plt.xlabel("Year")
plt.ylabel("Number of Aggravated Assault Cases")
plt.title("Aggravated Assault Cases 2011-2020")

plt.show()

# %%
drug_abuse = national_df["Drug Abuse Violations"]
year = national_df["Year"]

plt.plot(year, drug_abuse)
plt.xlabel("Year")
plt.ylabel("Number of Drug Abuse Violations (millions)")
plt.title("Drug Abuse Violations 2011-2020")

plt.show()

# %%
weapons = national_df["Weapons: Carrying, Possessing, Etc."]
year = national_df["Year"]

plt.plot(year, weapons)
plt.xlabel("Year")
plt.ylabel("Number of Weapons Violations")
plt.title("Weapons Violations 2011-2020")

plt.show()
